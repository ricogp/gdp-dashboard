# %% [markdown]
# ### Import das Bases

# %%
import numpy as np
import pandas as pd
import datetime

# %%
base = pd.read_csv('df_final_cobertura_historico_updated.csv')

# Import base crunchbase do mês de análise atual
crunhbase_df = pd.read_csv('funding-rounds-29-08-2024.csv')

# Import base domnique atualizada contendo o mês de análise
domo_df = pd.read_csv('domo_all_companies_2024_08_29.csv')

# %% [markdown]
# ### Formatação de Bases

# %%
#Retirando Negócio do nome das startups da base DOMO
domo_df['name'] = domo_df['name'].str.replace('Negócio ', '')

domo_df['name modified'] = domo_df['name'].str.replace(' ', '').str.lower()

#Retirando startups com o stagename Deleted e Url vazia
domo_df = domo_df[domo_df['stagename'] != 'Deleted']
domo_df_url = domo_df[~domo_df['url'].isna()]

# %%
# Base Crunchbase
crunhbase_df['Announced Date'] = pd.to_datetime(crunhbase_df['Announced Date'])

# Extract the year and create a new "year" column
crunhbase_df['Year'] = crunhbase_df['Announced Date'].dt.year

# Limpando Url da base do CrunchBase
crunhbase_df['Organization Website'] = crunhbase_df['Organization Website'].str.replace('http://www.', '').str.replace('https://www.', '').str.replace('http://', '').str.replace('https://', '').str.rstrip('/').str.replace('/app', '').str.replace('/en', '')
crunhbase_df['Organization Name Modified'] = crunhbase_df['Organization Name'].str.replace(' ', '').str.lower()

# %% [markdown]
# ### Merge Base Crunchbase e Domo

# %%
# Merge on Left na base Crunchbase, sendo assim as informações de rodada do crunchbase serão prevalentes

selected_columns = domo_df[['id','name modified', 'url', 'stagename']]
selected_columns_url = domo_df_url[['id','name modified', 'url', 'stagename']]

merged_name = pd.merge(crunhbase_df, selected_columns, how='left', left_on=['Organization Name Modified'], right_on=['name modified'])
merged_url = pd.merge(crunhbase_df, selected_columns_url, how='left', left_on=['Organization Website'], right_on=['url'])

merged_data = pd.concat([merged_name, merged_url], ignore_index=True)

# %%
# Fazendo limpeza do merge para não ter duplicada de name e url

# Find organizations with non-NaN 'Stagename'
orgs_with_stagename = merged_data.dropna(subset=['stagename'])['Organization Name']

# Filter the DataFrame to remove rows with NaN 'Stagename' for organizations with non-NaN 'Stagename'
merged_data = merged_data[~((merged_data['Organization Name'].isin(orgs_with_stagename)) & (merged_data['stagename'].isnull()))]

merged_data = merged_data.drop_duplicates()

# %% [markdown]
# ### Merge Base Classificada com Merged_Data acima (Crunchbase - DOMO do mês de análise)

# %%
# Supondo que seu DataFrame se chame df
base.rename(columns={'stagename_x': 'stagename'}, inplace=True)

# Filtrando as colunas
base_filtered = base.drop(columns=['Unnamed: 0','Analise descarte', 'stagename_y', 'Diversity Spotlight (US Headquarters Only)'])

# %%
# Criando colunas de tempo desde o anúncio da rodada e Month para Merged_data e Base_filtered

today = datetime.date.today()

merged_data['Announced Date'] = pd.to_datetime(merged_data['Announced Date'])
merged_data['Time Since Announced'] = today - merged_data['Announced Date'].dt.date

merged_data['Time Since Announced'] = pd.to_timedelta(merged_data['Time Since Announced'])
merged_data['Time Since Announced'] = merged_data['Time Since Announced'].dt.days

merged_data['Month'] = pd.to_datetime(merged_data['Announced Date']).dt.month

base_filtered['Announced Date'] = pd.to_datetime(base_filtered['Announced Date'])
base_filtered['Time Since Announced'] = today - base_filtered['Announced Date'].dt.date

base_filtered['Time Since Announced'] = pd.to_timedelta(base_filtered['Time Since Announced'])
base_filtered['Time Since Announced'] = base_filtered['Time Since Announced'].dt.days

# %% [markdown]
# ### Regras de classificação prévia, sem intervenção manual

# %%
# Aplicar a condição diretamente para criar a nova coluna 'Classification'

merged_data['Classification'] = np.where(
    merged_data['stagename'] == 'Portfolio', 'Portfolio',
    np.where(
        merged_data['Funding Type'] == 'Post-IPO Debt', 'Provavel Não se aplica',
          np.where(
              merged_data['stagename'].isin(['Cadastro Startup', 'Registered', 'Fazer Teste de Aderência']), 'Nao tivemos acesso',
              np.where(
                  (merged_data['stagename'] == 'Discard') & (merged_data['Total Funding Amount (in USD)'] < 1500000), 'Indefinido',
                  np.where(
                      merged_data['stagename'].isna(), 'Nao tivemos acesso',
                          np.where(
                              (merged_data['stagename'].isin(['Opportunity', 'Zero', 'P.Comitê 01', 'P.Comitê 02'])) & (merged_data['Total Funding Amount (in USD)'] < 1000000), 'Em análise',
                              'Pendente Classificação'  # Default value
                    )
                )
            )
        )
    )
)

# %%
merged_data['stagename'] = merged_data['stagename'].fillna('Nao tivemos acesso')

# %% [markdown]
# ### Verificando se a startup já está na base

# %%
# Realizar a junção com base no 'Organization Name'
merged_data = pd.merge( merged_data, base[['Organization Name', 'Classification']],
    on='Organization Name', how='left', suffixes=('', '_base'))

# Preencher a coluna 'Classification' original com valores de 'Classification_base' quando houver correspondência
merged_data['Classification'] = merged_data['Classification_base'].combine_first(merged_data['Classification'])

# Remover a coluna auxiliar 'Classification_base'
merged_data.drop(columns=['Classification_base'], inplace=True)

# Remover Duplicadas
merged_data = merged_data.drop_duplicates(subset=['Organization Name'])

merged_data
# Out:
#                 Organization Name  \
# 0                         Embraer
# 1                           Magie
# 3                          TEPMED
# 4                         ESG Now
# 6                            Afya
# 7            Agrion Agrisolutions
# 8                     Lavoro Agro
# 10             Scala Data Centers
# 11                   Cedro Textil
# 12                         Cayena
# 17                         Brendi
# 19                        Sipremo
# 20                        PsycoAI
# 21                          Facio
# 24                        Emitter
# 26  IDGeo - Inteligência Agrícola
#
#                                 Organization Name URL  \
# 0   https://www.crunchbase.com/organization/embrae...
# 1       https://www.crunchbase.com/organization/magie
# 3      https://www.crunchbase.com/organization/tepmed
# 4     https://www.crunchbase.com/organization/esg-now
# 6   https://www.crunchbase.com/organization/afya-e...
# 7   https://www.crunchbase.com/organization/agrion...
# 8   https://www.crunchbase.com/organization/lavoro...
# 10  https://www.crunchbase.com/organization/scala-...
# 11  https://www.crunchbase.com/organization/cedro-...
# 12  https://www.crunchbase.com/organization/poupachef
# 17     https://www.crunchbase.com/organization/brendi
# 19    https://www.crunchbase.com/organization/sipremo
# 20    https://www.crunchbase.com/organization/psycoai
# 21  https://www.crunchbase.com/organization/facio-...
# 24   https://www.crunchbase.com/organization/emite-aí
# 26  https://www.crunchbase.com/organization/idgeo-...
#
#                               Transaction Name  \
# 0                      Post-IPO Debt - Embraer
# 1                           Seed Round - Magie
# 3                       Venture Round - TEPMED
# 4                     Pre Seed Round - ESG Now
# 6                         Post-IPO Debt - Afya
# 7         Venture Round - Agrion Agrisolutions
# 8                  Post-IPO Debt - Lavoro Agro
# 10         Debt Financing - Scala Data Centers
# 11                Post-IPO Debt - Cedro Textil
# 12                           Series B - Cayena
# 17                         Seed Round - Brendi
# 19             Non Equity Assistance - Sipremo
# 20                       Angel Round - PsycoAI
# 21                            Series A - Facio
# 24                        Seed Round - Emitter
# 26  Seed Round - IDGeo - Inteligência Agrícola
#
#                                  Transaction Name URL  Total Funding Amount  \
# 0   https://www.crunchbase.com/funding_round/embra...          2.113180e+09
# 1   https://www.crunchbase.com/funding_round/magie...          2.800000e+07
# 3   https://www.crunchbase.com/funding_round/tepme...          2.000000e+07
# 4   https://www.crunchbase.com/funding_round/esg-n...          2.600000e+06
# 6   https://www.crunchbase.com/funding_round/afya-...          2.388841e+08
# 7   https://www.crunchbase.com/funding_round/agrio...          5.000000e+07
# 8   https://www.crunchbase.com/funding_round/lavor...          7.300000e+08
# 10  https://www.crunchbase.com/funding_round/scala...          4.540566e+08
# 11  https://www.crunchbase.com/funding_round/cedro...                   NaN
# 12  https://www.crunchbase.com/funding_round/poupa...          3.400000e+07
# 17  https://www.crunchbase.com/funding_round/brend...          1.220000e+06
# 19  https://www.crunchbase.com/funding_round/sipre...                   NaN
# 20  https://www.crunchbase.com/funding_round/psyco...          5.000000e+05
# 21  https://www.crunchbase.com/funding_round/facio...          1.750000e+07
# 24  https://www.crunchbase.com/funding_round/emite...          5.200000e+05
# 26  https://www.crunchbase.com/funding_round/idgeo...          1.170000e+07
#
#    Total Funding Amount Currency  Total Funding Amount (in USD)  \
# 0                            USD                   2.113180e+09
# 1                            BRL                   5.194349e+06
# 3                            BRL                   3.645445e+06
# 4                            BRL                   4.960730e+05
# 6                            USD                   2.388841e+08
# 7                            USD                   5.000000e+07
# 8                            BRL                   1.413400e+08
# 10                           USD                   4.540566e+08
# 11                           NaN                            NaN
# 12                           USD                   3.400000e+07
# 17                           USD                   1.220000e+06
# 19                           NaN                            NaN
# 20                           USD                   5.000000e+05
# 21                           USD                   1.750000e+07
# 24                           USD                   5.200000e+05
# 26                           BRL                   2.384070e+06
#
#                 Funding Type  \
# 0              Post-IPO Debt
# 1                       Seed
# 3   Venture - Series Unknown
# 4                   Pre-Seed
# 6              Post-IPO Debt
# 7   Venture - Series Unknown
# 8              Post-IPO Debt
# 10            Debt Financing
# 11             Post-IPO Debt
# 12                  Series B
# 17                      Seed
# 19     Non-equity Assistance
# 20                     Angel
# 21                  Series A
# 24                      Seed
# 26                      Seed
#
#                               Organization Industries Announced Date  ...  \
# 0    Aerospace, Commercial, Industrial, Manufacturing     2024-08-06  ...
# 1                    Information Technology, Internet     2024-08-22  ...
# 3                         Financial Services, FinTech     2024-08-15  ...
# 4                           CleanTech, SaaS, Software     2024-08-21  ...
# 6   EdTech, Education, Health Care, Higher Educati...     2024-08-07  ...
# 7                    AgTech, Biotechnology, Fertility     2024-08-27  ...
# 8                     Agriculture, Productivity Tools     2024-08-02  ...
# 10  Data Center, Data Storage, Information Technology     2024-08-20  ...
# 11                                  Fashion, Textiles     2024-08-02  ...
# 12  B2B, E-Commerce, Food and Beverage, Informatio...     2024-07-30  ...
# 17  Artificial Intelligence (AI), Food and Beverag...     2024-08-05  ...
# 19  Artificial Intelligence (AI), Electrical Distr...     2024-07-31  ...
# 20     Health Care, Health Insurance, Personal Health     2024-08-12  ...
# 21               Banking, Financial Services, FinTech     2024-08-08  ...
# 24                             Information Technology     2024-08-26  ...
# 26  Agriculture, AgTech, Artificial Intelligence (...     2024-08-02  ...
#
#                                 Organization Location  Year  \
# 0         São Paulo, Sao Paulo, Brazil, South America  2024
# 1         São Paulo, Sao Paulo, Brazil, South America  2024
# 3   Santa Maria, Rio Grande do Sul, Brazil, South ...  2024
# 4   Taquara, Rio Grande do Sul, Brazil, South America  2024
# 6           Minas Gerais, Acre, Brazil, South America  2024
# 7     Uberlândia, Minas Gerais, Brazil, South America  2024
# 8       Munhoz De Melo, Parana, Brazil, South America  2024
# 10        São Paulo, Sao Paulo, Brazil, South America  2024
# 11  Belo Horizonte, Minas Gerais, Brazil, South Am...  2024
# 12        São Paulo, Sao Paulo, Brazil, South America  2024
# 17  São José Dos Campos, Sao Paulo, Brazil, South ...  2024
# 19        São Paulo, Sao Paulo, Brazil, South America  2024
# 20        São Paulo, Sao Paulo, Brazil, South America  2024
# 21        São Paulo, Sao Paulo, Brazil, South America  2024
# 24    Blumenau, Santa Catarina, Brazil, South America  2024
# 26       Piracicaba, Sao Paulo, Brazil, South America  2024
#
#     Organization Name Modified       id name modified             url  \
# 0                      embraer      NaN           NaN             NaN
# 1                        magie  26228.0         magie    magie.com.br
# 3                       tepmed      NaN           NaN             NaN
# 4                       esgnow  20428.0        esgnow       esgnow.co
# 6                         afya      NaN           NaN             NaN
# 7          agrionagrisolutions      NaN           NaN             NaN
# 8                   lavoroagro      NaN           NaN             NaN
# 10            scaladatacenters      NaN           NaN             NaN
# 11                 cedrotextil      NaN           NaN             NaN
# 12                      cayena  19457.0        cayena      cayena.com
# 17                      brendi  25455.0        brendi   brendi.com.br
# 19                     sipremo  11024.0       sipremo     sipremo.com
# 20                     psycoai      NaN           NaN             NaN
# 21                       facio  10274.0         facio    facio.com.br
# 24                     emitter  22607.0       emiteaí  emiteai.com.br
# 26  idgeo-inteligênciaagrícola   9540.0         idgeo    idgeo.com.br
#
#                    stagename Time Since Announced  Month  \
# 0         Nao tivemos acesso                   23      8
# 1   Fazer Teste de Aderência                    7      8
# 3         Nao tivemos acesso                   14      8
# 4                  Portfolio                    8      8
# 6         Nao tivemos acesso                   22      8
# 7         Nao tivemos acesso                    2      8
# 8         Nao tivemos acesso                   27      8
# 10        Nao tivemos acesso                    9      8
# 11        Nao tivemos acesso                   27      8
# 12                   Discard                   30      7
# 17               Opportunity                   24      8
# 19                   Discard                   29      7
# 20        Nao tivemos acesso                   17      8
# 21                   Discard                   21      8
# 24               Opportunity                    3      8
# 26                   Discard                   27      8
#
#             Classification
# 0   Provavel Não se aplica
# 1       Nao tivemos acesso
# 3       Nao tivemos acesso
# 4                Portfolio
# 6   Provavel Não se aplica
# 7            Não se aplica
# 8            Não se aplica
# 10      Nao tivemos acesso
# 11           Não se aplica
# 12          Falso Negativo
# 17              Em análise
# 19              Indefinido
# 20      Nao tivemos acesso
# 21      Nao tivemos acesso
# 24              Em análise
# 26  Pendente Classificação
#
# [16 rows x 36 columns]

# %% [markdown]
# ### Unindo base histórica e atualização do mês

# %%
# Supondo que merged_data e base_filtered sejam os DataFrames que você quer concatenar
combined_data = pd.concat([merged_data, base_filtered])

# Removendo duplicatas
combined_data = combined_data.drop_duplicates(subset=['Organization Name', 'Announced Date', 'stagename'])

# %%
# Convertendo 'Announced Date' para o tipo datetime
combined_data['Announced Date'] = pd.to_datetime(combined_data['Announced Date'], errors='coerce')

# Ordenando pelo 'Announced Date'
combined_data = combined_data.sort_values(by='Announced Date')
combined_data = combined_data.reset_index(drop=True)

# %%
combined_data = combined_data[combined_data['Classification'] != 'Não se aplica']

# %%
combined_data.to_csv('df_final_cobertura_historico.csv', index=False)
